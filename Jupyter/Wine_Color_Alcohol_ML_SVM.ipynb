# %%
#import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import svm
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# %matplotlib inline

# %%
#import Csv
redWine = pd.read_csv('/Users/heath/Project-3-Wine/Data/wineQualityReds.csv', index_col=0)
whiteWine = pd.read_csv('/Users/heath/Project-3-Wine/Data/wineQualityWhites.csv', index_col=0)

# %%
#add color to the csvs based on data location
redWine['wine_color'] = 'red'
whiteWine['wine_color'] = 'white'

# %%
#rename white wine data set columns that are mismatched to red wine data
whiteWine.rename({"fixed.acidity": "fixed acidity",
                 "volatile.acidity": "volatile acidity",
                 "citric.acid": "citric acid",
                 "residual.sugar": "residual sugar",
                 "free.sulfur.dioxide": "free sulfur dioxide",
                 "total.sulfur.dioxide": "total sulfur dioxide",
                 "pH": "ph"},
                axis = "columns", inplace = True)


whiteWine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            7.0              0.27         0.36            20.7      0.045
# 2            6.3              0.30         0.34             1.6      0.049
# 3            8.1              0.28         0.40             6.9      0.050
# 4            7.2              0.23         0.32             8.5      0.058
# 5            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    ph  sulphates  \
# 1                 45.0                 170.0   1.0010  3.00       0.45
# 2                 14.0                 132.0   0.9940  3.30       0.49
# 3                 30.0                  97.0   0.9951  3.26       0.44
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality wine_color
# 1      8.8        6      white
# 2      9.5        6      white
# 3     10.1        6      white
# 4      9.9        6      white
# 5      9.9        6      white

# %%
#concatenate red & white wine frames
frames = [redWine, whiteWine]
wine = pd.concat(frames)
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            7.4              0.70         0.00             1.9      0.076
# 2            7.8              0.88         0.00             2.6      0.098
# 3            7.8              0.76         0.04             2.3      0.092
# 4           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    ph  sulphates  \
# 1                 11.0                  34.0   0.9978  3.51       0.56
# 2                 25.0                  67.0   0.9968  3.20       0.68
# 3                 15.0                  54.0   0.9970  3.26       0.65
# 4                 17.0                  60.0   0.9980  3.16       0.58
# 5                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality wine_color
# 1      9.4        5        red
# 2      9.8        5        red
# 3      9.8        5        red
# 4      9.8        6        red
# 5      9.4        5        red

# %%
#summarize wine data----- white wine data much more prevalent
wine.info()
wine['wine_color'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6497 entries, 1 to 4898
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   ph                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  wine_color            6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 710.6+ KB
# white    4898
# red      1599
# Name: wine_color, dtype: int64

# %%
#encode white wine color data
label_color = LabelEncoder()
wine['wine_color']= label_color.fit_transform(wine['wine_color'])
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            7.4              0.70         0.00             1.9      0.076
# 2            7.8              0.88         0.00             2.6      0.098
# 3            7.8              0.76         0.04             2.3      0.092
# 4           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    ph  sulphates  \
# 1                 11.0                  34.0   0.9978  3.51       0.56
# 2                 25.0                  67.0   0.9968  3.20       0.68
# 3                 15.0                  54.0   0.9970  3.26       0.65
# 4                 17.0                  60.0   0.9980  3.16       0.58
# 5                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  wine_color
# 1      9.4        5           0
# 2      9.8        5           0
# 3      9.8        5           0
# 4      9.8        6           0
# 5      9.4        5           0

# %%
#Separate dataset as response variable & feature variable
X = wine.drop('wine_color', axis =1)
y = wine['wine_color']

# %%
#split train data & test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state =42)

# %%
#apply scaling to get optimized result- limits bias by not allowing large numbers in a field to overpower smaller numbers in another
#ie sulfur v chlorides

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc = sc.transform(X_test)

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
clf_pred = clf.predict(X_test)

# %%
print(classification_report(y_test, clf_pred))
print(confusion_matrix(y_test, clf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       341
#            1       0.99      1.00      1.00       959
#
#     accuracy                           0.99      1300
#    macro avg       1.00      0.99      0.99      1300
# weighted avg       0.99      0.99      0.99      1300
#
# [[335   6]
#  [  1 958]]

# %%
#understand summary metrics to get feel for bins
wine['alcohol'].describe()
# Out:
# count    6497.000000
# mean       10.491801
# std         1.192712
# min         8.000000
# 25%         9.500000
# 50%        10.300000
# 75%        11.300000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
# create bins 
bins = (8, 9.5, 10.3, 11.3, 14.9)
bin_names = ['low_alcohol', 'medium_low', 'medium_high','high_alcohol']
wine['alcohol'] = pd.cut(wine['alcohol'], bins, labels=bin_names)
wine['alcohol'].unique()
# Out:
# [low_alcohol, medium_low, medium_high, high_alcohol, NaN]
# Categories (4, object): [low_alcohol < medium_low < medium_high < high_alcohol]

# %%
wine["alcohol"]= wine["alcohol"].astype(str)
label_alc = LabelEncoder()
wine['alcohol']= label_color.fit_transform(wine['alcohol'])
wine.head(40)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1             7.4             0.700         0.00             1.9      0.076
# 2             7.8             0.880         0.00             2.6      0.098
# 3             7.8             0.760         0.04             2.3      0.092
# 4            11.2             0.280         0.56             1.9      0.075
# 19                  6.0                  29.0   0.9974  3.38       0.50
# 20                 17.0                  56.0   0.9969  3.04       1.08
# 21                 29.0                  60.0   0.9968  3.39       0.53
# 22                 23.0                  71.0   0.9982  3.52       0.65
# 23                 10.0                  37.0   0.9966  3.17       0.91
# 24                  9.0                  67.0   0.9968  3.17       0.53
# 25                 21.0                  40.0   0.9968  3.43       0.63
# 26                 11.0                  23.0   0.9955  3.34       0.56
# 27                  4.0                  11.0   0.9962  3.28       0.59
# 28                 10.0                  37.0   0.9966  3.17       0.91
# 29                 14.0                  35.0   0.9972  3.47       0.55
# 30                  8.0                  16.0   0.9964  3.38       0.59
# 31                 17.0                  82.0   0.9958  3.35       0.54
# 32                 22.0                  37.0   0.9966  3.46       0.57
# 33                 15.0                 113.0   0.9966  3.17       0.66
# 34                 40.0                  83.0   0.9993  3.45       0.52
# 35                 13.0                  50.0   0.9957  3.38       0.55
# 36                  5.0                  18.0   0.9986  3.40       0.55
# 37                  3.0                  15.0   0.9975  3.42       0.60
# 38                 13.0                  30.0   0.9968  3.23       0.73
# 39                  7.0                  19.0   0.9940  3.50       0.48
# 40                 12.0                  87.0   0.9978  3.33       0.83
#
#     alcohol  quality  wine_color
# 1         1        5           0
# 2         3        5           0
# 3         3        5           0
# 4         3        6           0
# 5         1        5           0
# 6         1        5           0
# 7         1        5           0
# 8         3        7           0
# 9         1        7           0
# 10        2        5           0
# 11        1        5           0
# 12        2        5           0
# 13        3        5           0
# 14        1        5           0
# 15        1        5           0
# 16        1        5           0
# 17        2        7           0
# 18        1        5           0
# 19        1        4           0
# 20        1        6           0
# 21        1        6           0
# 22        3        5           0
# 23        1        5           0
# 24        1        5           0
# 25        3        6           0
# 26        1        5           0
# 27        1        5           0
# 28        1        5           0
# 29        1        5           0
# 30        3        6           0
# 31        3        5           0
# 32        2        6           0
# 33        3        5           0
# 34        1        6           0
# 35        1        5           0
# 36        3        6           0
# 37        2        6           0
# 38        3        7           0
# 39        3        4           0
# 40        2        5           0

# %%
#0=high
#1=low_alcohol
#2=medium-high
#3=medium-low


#Separate dataset as response variable & feature variable
X = wine.drop('alcohol', axis =1)
y = wine['alcohol']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state =42)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc = sc.transform(X_test)

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
clf_pred = clf.predict(X_test)

# %%
print(classification_report(y_test, clf_pred))
print(confusion_matrix(y_test, clf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87       328
#            1       0.80      0.79      0.79       368
#            2       0.69      0.70      0.69       325
#            3       0.57      0.60      0.58       279
#
#     accuracy                           0.74      1300
#    macro avg       0.74      0.73      0.73      1300
# weighted avg       0.74      0.74      0.74      1300
#
# [[277   0  50   1]
#  [  0 289   7  72]
#  [ 31  11 229  54]
#  [  1  63  48 167]]
