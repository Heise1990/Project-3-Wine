# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
wine_data = pd.read_csv('/Users/marinaduarte/Documents/Project-3-Wine/winemag-data_first150k.csv')

# %%
wine_data
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
for_points = wine_data.dropna(subset=['points'])
for_points
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
#points = wine_data['points'].astype(int) # or str for string
for_points = for_points.astype({"points": int})

# %%
for_points.dtypes
# Out:
# Unnamed: 0       int64
# country         object
# description     object
# designation     object
# points           int64
# price          float64
# province        object
# region_1        object
# region_2        object
# variety         object
# winery          object
# dtype: object

# %%
country_points = for_points.groupby(['country'])['points'].mean()
#country_points2 = country_points.to_frame()
#country_points2['points'].unstack()
#country_points2.sort_values(by='points', ascending = False)
country_points
# Out:
# country
# Albania                   88.000000
# Argentina                 85.996093
# Australia                 87.892475
# Austria                   89.276742
# Bosnia and Herzegovina    84.750000
# Brazil                    83.240000
# Bulgaria                  85.467532
# Canada                    88.239796
# Chile                     86.296768
# China                     82.000000
# Croatia                   86.280899
# Cyprus                    85.870968
# Czech Republic            85.833333
# Egypt                     83.666667
# England                   92.888889
# France                    88.925870
# Georgia                   85.511628
# Germany                   88.626427
# Greece                    86.117647
# Hungary                   87.329004
# India                     87.625000
# Israel                    87.176190
# Italy                     88.413664
# Japan                     85.000000
# Lebanon                   85.702703
# Lithuania                 84.250000
# ...

# %%
country_points.plot.bar(figsize = [20,10])

# %%
pointsDF = for_points.merge(country_points, how='inner', left_on=["country"], right_on=["country"])
pointsDF
# Out:
#         Unnamed: 0    country  \
# 0                0         US
# 1                2         US
# 2                3         US
# 3                8         US
# 4                9         US
# ...            ...        ...
# 150920      119008      Egypt
# 150921      119894      Egypt
# 150922      138139    Tunisia
# 150923      139931    Tunisia
# 150924      144054  US-France
#
#                                               description  \
# 0       This tremendous 100% varietal wine hails from ...
# 1       Mac Watson honors the memory of a wine once ma...
# 2       This spent 20 months in 30% new French oak, an...
# 3       This re-named vineyard was formerly bottled as...
# 4       The producer sources from two blocks of the vi...
# ...                                                   ...
# 150920  This fresh, approachable Chenin starts with br...
# 150921  The character of this feminine, aromatic Viogn...
# 150922  An irresistible rosé from Tunisia (made by Sic...
# ...

# %%
#fig, ax = plt.subplots(figsize=(20,10))
#plt.bar(pointsDF['country'], pointsDF['points_y'])
#plt.xticks(rotation=90)
#ax.set_ylim([80,95])
#plt.title('Average points by country')
#plt.show()

# %%
#points = wine_data['points'].astype(int) # or str for string
for_price = wine_data.dropna(subset=['price'])
for_price = for_price.astype({"price": int})
for_price.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96    235      California
# 1  Carodorum Selección Especial Reserva      96    110  Northern Spain
# 2         Special Selected Late Harvest      96     90      California
# 3                               Reserve      96     65          Oregon
# 4                            La Brûlade      95     66        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
country_price = for_price.groupby(['country'])['price'].mean()

country_price
# Out:
# country
# Albania                   20.000000
# Argentina                 20.794881
# Australia                 31.258480
# Austria                   31.192106
# Bosnia and Herzegovina    12.750000
# Brazil                    19.920000
# Bulgaria                  11.545455
# Canada                    34.628866
# Chile                     19.344780
# China                     20.333333
# Croatia                   23.108434
# Cyprus                    15.483871
# Czech Republic            18.000000
# England                   47.500000
# France                    45.619885
# Georgia                   18.581395
# Germany                   39.011078
# Greece                    21.747706
# Hungary                   44.204348
# India                     13.875000
# Israel                    31.304918
# Italy                     37.547913
# Japan                     24.000000
# Lebanon                   25.432432
# Lithuania                 10.000000
# Luxembourg                40.666667
# ...

# %%
priceDF = for_price.merge(country_price, how='inner', left_on=["country"], right_on=["country"])

# %%
#fig, ax = plt.subplots(figsize=(20,10))
#plt.bar(priceDF['country'], priceDF['price_y'])
# plt.xticks(rotation=90)
# ax.set_ylim([5,55])
# plt.title('Average price by country')
# plt.show()

# %%
for_price.describe()
# Out:
#           Unnamed: 0         points          price
# count  137235.000000  137235.000000  137235.000000
# mean    75729.232018      87.787919      33.131482
# std     43868.140942       3.221680      36.322536
# min         0.000000      80.000000       4.000000
# 25%     37586.500000      86.000000      16.000000
# 50%     75725.000000      88.000000      24.000000
# 75%    114108.500000      90.000000      40.000000
# max    150929.000000     100.000000    2300.000000

# %%
import tensorflow as tf

import numpy as np 
import seaborn as sns
import sklearn.model_selection as sk
